# %% [markdown]
# # Convolutional Autoencoder
#
# Sticking with the MNIST dataset, let's improve our autoencoder's performance using convolutional layers. Again, loading modules and the data.

# %%
# %matplotlib inline

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets('MNIST_data', validation_size=0)
# Out:
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
img = mnist.train.images[2]
plt.imshow(img.reshape((28, 28)), cmap='Greys_r')

# %% [markdown]
# ## Network Architecture
#
# The encoder part of the network will be a typical convolutional pyramid. Each convolutional layer will be followed by a max-pooling layer to reduce the dimensions of the layers. The decoder though might be something new to you. The decoder needs to convert from a narrow representation to a wide reconstructed image. For example, the representation could be a 4x4x8 max-pool layer. This is the output of the encoder, but also the input to the decoder. We want to get a 28x28x1 image out from the decoder so we need to work our way back up from the narrow decoder input layer. A schematic of the network is shown below.
#
# ![Convolutional Autoencoder](assets/convolutional_autoencoder.png)
#
# Here our final encoder layer has size 4x4x8 = 128. The original images have size 28x28 = 784, so the encoded vector is roughly 16% the size of the original image. These are just suggested sizes for each of the layers. Feel free to change the depths and sizes, but remember our goal here is to find a small representation of the input data.
#
# ### What's going on with the decoder
#
# Okay, so the decoder has these "Upsample" layers that you might not have seen before. First off, I'll discuss a bit what these layers *aren't*. Usually, you'll see **deconvolutional** layers used to increase the width and height of the layers. They work almost exactly the same as convolutional layers, but it reverse. A stride in the input layer results in a larger stride in the deconvolutional layer. For example, if you have a 3x3 kernel, a 3x3 patch in the input layer will be reduced to one unit in a convolutional layer. Comparatively, one unit in the input layer will be expanded to a 3x3 path in a deconvolutional layer. Deconvolution is often called "transpose convolution" which is what you'll find with the TensorFlow API, with [`tf.nn.conv2d_transpose`](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d_transpose).
#
# However, deconvolutional layers can lead to artifacts in the final images, such as checkerboard patterns. This is due to overlap in the kernels which can be avoided by setting the stride and kernel size equal. In [this Distill article](http://distill.pub/2016/deconv-checkerboard/) from Augustus Odena, *et al*, the authors show that these checkerboard artifacts can be avoided by resizing the layers using nearest neighbor or bilinear interpolation (upsampling) followed by a convolutional layer. In TensorFlow, this is easily done with [`tf.image.resize_images`](https://www.tensorflow.org/versions/r1.1/api_docs/python/tf/image/resize_images), followed by a convolution. Be sure to read the Distill article to get a better understanding of deconvolutional layers and why we're using upsampling.
#
# > **Exercise:** Build the network shown above. Remember that a convolutional layer with strides of 1 and 'same' padding won't reduce the height and width. That is, if the input is 28x28 and the convolution layer has stride = 1 and 'same' padding, the convolutional layer will also be 28x28. The max-pool layers are used the reduce the width and height. A stride of 2 will reduce the size by 2. Odena *et al* claim that nearest neighbor interpolation works best for the upsampling, so make sure to include that as a parameter in `tf.image.resize_images` or use [`tf.image.resize_nearest_neighbor`]( `https://www.tensorflow.org/api_docs/python/tf/image/resize_nearest_neighbor).

# %%
learning_rate = 0.001
inputs_ = tf.placeholder(tf.float32, shape=(None, 28, 28, 1))
targets_ = tf.placeholder(tf.float32, shape=(None, 28, 28, 1))

### Encoder
conv1 = tf.layers.conv2d(inputs_, 16, (3,3), strides=(1,1), padding='same', activation=tf.nn.relu)
# Now 28x28x16
maxpool1 = tf.layers.max_pooling2d(conv1, (1,1), strides=(2,2), padding='same')
# Now 14x14x16
conv2 = tf.layers.conv2d(maxpool1, 8, (3,3), strides=(1,1), padding='same', activation=tf.nn.relu)
# Now 14x14x8
maxpool2 = tf.layers.max_pooling2d(conv2, (1,1), strides=(2,2), padding='same')
# Now 7x7x8
conv3 = tf.layers.conv2d(maxpool2, 8, (3,3), strides=(1,1), padding='same', activation=tf.nn.relu)
# Now 7x7x8
encoded = tf.layers.max_pooling2d(conv3, (1,1), strides=(2,2), padding='same')
# Now 4x4x8

### Decoder
upsample1 = tf.image.resize_images(encoded, [7, 7])
# Now 7x7x8
conv4 = tf.layers.conv2d(upsample1, 8, (3,3), strides=(1,1), padding='same')
# Now 7x7x8
upsample2 = tf.image.resize_images(conv4, [14, 14])
# Now 14x14x8
conv5 = tf.layers.conv2d(upsample2, 8, (3,3), strides=(1,1), padding='same')
# Now 14x14x8
upsample3 = tf.image.resize_images(conv5, [28, 28])
# Now 28x28x8
conv6 = tf.layers.conv2d(upsample3, 16, (3,3), strides=(1,1), padding='same')
# Now 28x28x16

logits = tf.layers.conv2d(conv6, 1, (3,3), strides=(1,1), padding='same')
#Now 28x28x1

# Pass logits through sigmoid to get reconstructed image
decoded = tf.sigmoid(logits)

# Pass logits through sigmoid and calculate the cross-entropy loss
loss = tf.nn.sigmoid_cross_entropy_with_logits(labels=targets_, logits=logits)

# Get cost and define the optimizer
cost = tf.reduce_mean(loss)
opt = tf.train.AdamOptimizer(learning_rate).minimize(cost)

# %% [markdown]
# ## Training
#
# As before, here wi'll train the network. Instead of flattening the images though, we can pass them in as 28x28x1 arrays.

# %%
sess = tf.Session(config=tf.ConfigProto(
  intra_op_parallelism_threads=8))

# %%
epochs = 20
batch_size = 200
sess.run(tf.global_variables_initializer())
for e in range(epochs):
    for ii in range(mnist.train.num_examples//batch_size):
        batch = mnist.train.next_batch(batch_size)
        imgs = batch[0].reshape((-1, 28, 28, 1))
        batch_cost, _ = sess.run([cost, opt], feed_dict={inputs_: imgs,
                                                         targets_: imgs})
        if ii % 30 == 0:
            print("Epoch: {}/{}...".format(e+1, epochs), "Training loss: {:.4f}".format(batch_cost))
    print("Epoch: {}/{}...".format(e+1, epochs), "Training loss: {:.4f}".format(batch_cost))
# Out:
# Epoch: 1/20... Training loss: 0.6925
# Epoch: 1/20... Training loss: 0.4320
# Epoch: 1/20... Training loss: 0.2536
# Epoch: 1/20... Training loss: 0.2248
# Epoch: 1/20... Training loss: 0.2036
# Epoch: 1/20... Training loss: 0.2061
# Epoch: 1/20... Training loss: 0.1938
# Epoch: 1/20... Training loss: 0.1987
# Epoch: 1/20... Training loss: 0.1919
# Epoch: 1/20... Training loss: 0.1892
# Epoch: 1/20... Training loss: 0.1895
# Epoch: 2/20... Training loss: 0.1871
# Epoch: 2/20... Training loss: 0.1857
# Epoch: 2/20... Training loss: 0.1853
# Epoch: 2/20... Training loss: 0.1820
# Epoch: 2/20... Training loss: 0.1793
# Epoch: 2/20... Training loss: 0.1813
# Epoch: 2/20... Training loss: 0.1761
# Epoch: 2/20... Training loss: 0.1761
# Epoch: 2/20... Training loss: 0.1663
# Epoch: 2/20... Training loss: 0.1655
# Epoch: 2/20... Training loss: 0.1602
# Epoch: 3/20... Training loss: 0.1669
# Epoch: 3/20... Training loss: 0.1667
# Epoch: 3/20... Training loss: 0.1659
# Epoch: 3/20... Training loss: 0.1669
# Epoch: 3/20... Training loss: 0.1646
# Epoch: 3/20... Training loss: 0.1633
# Epoch: 3/20... Training loss: 0.1572
# Epoch: 3/20... Training loss: 0.1584
# Epoch: 3/20... Training loss: 0.1655
# Epoch: 3/20... Training loss: 0.1577
# Epoch: 3/20... Training loss: 0.1559
# Epoch: 4/20... Training loss: 0.1542
# Epoch: 4/20... Training loss: 0.1597
# Epoch: 4/20... Training loss: 0.1484
# Epoch: 4/20... Training loss: 0.1514
# Epoch: 4/20... Training loss: 0.1556
# Epoch: 4/20... Training loss: 0.1512
# Epoch: 4/20... Training loss: 0.1482
# Epoch: 4/20... Training loss: 0.1502
# Epoch: 4/20... Training loss: 0.1556
# Epoch: 4/20... Training loss: 0.1506
# Epoch: 4/20... Training loss: 0.1525
# Epoch: 5/20... Training loss: 0.1505
# Epoch: 5/20... Training loss: 0.1479
# Epoch: 5/20... Training loss: 0.1518
# Epoch: 5/20... Training loss: 0.1467
# Epoch: 5/20... Training loss: 0.1521
# Epoch: 5/20... Training loss: 0.1461
# Epoch: 5/20... Training loss: 0.1452
# Epoch: 5/20... Training loss: 0.1476
# Epoch: 5/20... Training loss: 0.1506
# Epoch: 5/20... Training loss: 0.1445
# Epoch: 5/20... Training loss: 0.1434
# Epoch: 6/20... Training loss: 0.1471
# Epoch: 6/20... Training loss: 0.1484
# Epoch: 6/20... Training loss: 0.1426
# Epoch: 6/20... Training loss: 0.1458
# Epoch: 6/20... Training loss: 0.1524
# Epoch: 6/20... Training loss: 0.1417
# Epoch: 6/20... Training loss: 0.1479
# Epoch: 6/20... Training loss: 0.1489
# Epoch: 6/20... Training loss: 0.1414
# Epoch: 6/20... Training loss: 0.1404
# Epoch: 6/20... Training loss: 0.1454
# Epoch: 7/20... Training loss: 0.1438
# Epoch: 7/20... Training loss: 0.1402
# Epoch: 7/20... Training loss: 0.1360
# Epoch: 7/20... Training loss: 0.1399
# Epoch: 7/20... Training loss: 0.1394
# Epoch: 7/20... Training loss: 0.1428
# Epoch: 7/20... Training loss: 0.1374
# Epoch: 7/20... Training loss: 0.1377
# Epoch: 7/20... Training loss: 0.1378
# Epoch: 7/20... Training loss: 0.1414
# Epoch: 7/20... Training loss: 0.1360
# Epoch: 8/20... Training loss: 0.1434
# Epoch: 8/20... Training loss: 0.1403
# Epoch: 8/20... Training loss: 0.1372
# Epoch: 8/20... Training loss: 0.1374
# Epoch: 8/20... Training loss: 0.1351
# Epoch: 8/20... Training loss: 0.1365
# Epoch: 8/20... Training loss: 0.1379
# Epoch: 8/20... Training loss: 0.1360
# Epoch: 8/20... Training loss: 0.1397
# Epoch: 8/20... Training loss: 0.1387
# Epoch: 8/20... Training loss: 0.1413
# Epoch: 9/20... Training loss: 0.1439
# Epoch: 9/20... Training loss: 0.1322
# Epoch: 9/20... Training loss: 0.1402
# Epoch: 9/20... Training loss: 0.1377
# Epoch: 9/20... Training loss: 0.1396
# Epoch: 9/20... Training loss: 0.1347
# Epoch: 9/20... Training loss: 0.1347
# Epoch: 9/20... Training loss: 0.1366
# Epoch: 9/20... Training loss: 0.1328
# Epoch: 9/20... Training loss: 0.1323
# Epoch: 9/20... Training loss: 0.1370
# Epoch: 10/20... Training loss: 0.1329
# Epoch: 10/20... Training loss: 0.1378
# Epoch: 10/20... Training loss: 0.1334
# Epoch: 10/20... Training loss: 0.1327
# Epoch: 10/20... Training loss: 0.1369
# Epoch: 10/20... Training loss: 0.1322
# Epoch: 10/20... Training loss: 0.1357
# Epoch: 10/20... Training loss: 0.1305
# Epoch: 10/20... Training loss: 0.1328
# Epoch: 10/20... Training loss: 0.1331
# Epoch: 10/20... Training loss: 0.1292
# Epoch: 11/20... Training loss: 0.1319
# Epoch: 11/20... Training loss: 0.1325
# Epoch: 11/20... Training loss: 0.1252
# Epoch: 11/20... Training loss: 0.1356
# Epoch: 11/20... Training loss: 0.1292
# Epoch: 11/20... Training loss: 0.1239
# Epoch: 11/20... Training loss: 0.1338
# Epoch: 11/20... Training loss: 0.1317
# Epoch: 11/20... Training loss: 0.1333
# Epoch: 11/20... Training loss: 0.1273
# Epoch: 11/20... Training loss: 0.1314
# Epoch: 12/20... Training loss: 0.1293
# Epoch: 12/20... Training loss: 0.1310
# Epoch: 12/20... Training loss: 0.1338
# Epoch: 12/20... Training loss: 0.1322
# Epoch: 12/20... Training loss: 0.1261
# Epoch: 12/20... Training loss: 0.1246
# Epoch: 12/20... Training loss: 0.1281
# Epoch: 12/20... Training loss: 0.1289
# Epoch: 12/20... Training loss: 0.1307
# Epoch: 12/20... Training loss: 0.1296
# Epoch: 12/20... Training loss: 0.1273
# Epoch: 13/20... Training loss: 0.1300
# Epoch: 13/20... Training loss: 0.1313
# Epoch: 13/20... Training loss: 0.1284
# Epoch: 13/20... Training loss: 0.1270
# Epoch: 13/20... Training loss: 0.1258
# Epoch: 13/20... Training loss: 0.1242
# Epoch: 13/20... Training loss: 0.1288
# Epoch: 13/20... Training loss: 0.1291
# Epoch: 13/20... Training loss: 0.1241
# Epoch: 13/20... Training loss: 0.1286
# Epoch: 13/20... Training loss: 0.1258
# Epoch: 14/20... Training loss: 0.1292
# Epoch: 14/20... Training loss: 0.1299
# Epoch: 14/20... Training loss: 0.1256
# Epoch: 14/20... Training loss: 0.1283
# Epoch: 14/20... Training loss: 0.1264
# Epoch: 14/20... Training loss: 0.1344
# Epoch: 14/20... Training loss: 0.1250
# Epoch: 14/20... Training loss: 0.1281
# Epoch: 14/20... Training loss: 0.1249
# Epoch: 14/20... Training loss: 0.1243
# Epoch: 14/20... Training loss: 0.1249
# Epoch: 15/20... Training loss: 0.1305
# Epoch: 15/20... Training loss: 0.1239
# Epoch: 15/20... Training loss: 0.1269
# Epoch: 15/20... Training loss: 0.1246
# Epoch: 15/20... Training loss: 0.1222
# Epoch: 15/20... Training loss: 0.1260
# Epoch: 15/20... Training loss: 0.1208
# Epoch: 15/20... Training loss: 0.1229
# Epoch: 15/20... Training loss: 0.1271
# Epoch: 15/20... Training loss: 0.1240
# Epoch: 15/20... Training loss: 0.1241
# Epoch: 16/20... Training loss: 0.1264
# Epoch: 16/20... Training loss: 0.1270
# Epoch: 16/20... Training loss: 0.1271
# Epoch: 16/20... Training loss: 0.1244
# Epoch: 16/20... Training loss: 0.1246
# Epoch: 16/20... Training loss: 0.1259
# Epoch: 16/20... Training loss: 0.1279
# Epoch: 16/20... Training loss: 0.1241
# Epoch: 16/20... Training loss: 0.1238
# Epoch: 16/20... Training loss: 0.1262
# Epoch: 16/20... Training loss: 0.1223
# Epoch: 17/20... Training loss: 0.1234
# Epoch: 17/20... Training loss: 0.1247
# Epoch: 17/20... Training loss: 0.1227
# Epoch: 17/20... Training loss: 0.1213
# Epoch: 17/20... Training loss: 0.1215
# Epoch: 17/20... Training loss: 0.1211
# Epoch: 17/20... Training loss: 0.1195
# Epoch: 17/20... Training loss: 0.1252
# Epoch: 17/20... Training loss: 0.1215
# Epoch: 17/20... Training loss: 0.1242
# Epoch: 17/20... Training loss: 0.1236
# Epoch: 18/20... Training loss: 0.1257
# Epoch: 18/20... Training loss: 0.1246
# Epoch: 18/20... Training loss: 0.1236
# Epoch: 18/20... Training loss: 0.1181
# Epoch: 18/20... Training loss: 0.1215
# Epoch: 18/20... Training loss: 0.1256
# Epoch: 18/20... Training loss: 0.1199
# Epoch: 18/20... Training loss: 0.1241
# Epoch: 18/20... Training loss: 0.1217
# Epoch: 18/20... Training loss: 0.1239
# Epoch: 18/20... Training loss: 0.1235
# Epoch: 19/20... Training loss: 0.1156
# Epoch: 19/20... Training loss: 0.1208
# Epoch: 19/20... Training loss: 0.1199
# Epoch: 19/20... Training loss: 0.1244
# Epoch: 19/20... Training loss: 0.1218
# Epoch: 19/20... Training loss: 0.1245
# Epoch: 19/20... Training loss: 0.1178
# Epoch: 19/20... Training loss: 0.1167
# Epoch: 19/20... Training loss: 0.1227
# Epoch: 19/20... Training loss: 0.1190
# Epoch: 19/20... Training loss: 0.1206
# Epoch: 20/20... Training loss: 0.1281
# Epoch: 20/20... Training loss: 0.1241
# Epoch: 20/20... Training loss: 0.1188
# Epoch: 20/20... Training loss: 0.1229
# Epoch: 20/20... Training loss: 0.1273
# Epoch: 20/20... Training loss: 0.1238
# Epoch: 20/20... Training loss: 0.1242
# Epoch: 20/20... Training loss: 0.1212
# Epoch: 20/20... Training loss: 0.1191
# Epoch: 20/20... Training loss: 0.1224
# Epoch: 20/20... Training loss: 0.1186

# %%
fig, axes = plt.subplots(nrows=2, ncols=10, sharex=True, sharey=True, figsize=(20,4))
in_imgs = mnist.test.images[:10]
reconstructed = sess.run(decoded, feed_dict={inputs_: in_imgs.reshape((10, 28, 28, 1))})

for images, row in zip([in_imgs, reconstructed], axes):
    for img, ax in zip(images, row):
        ax.imshow(img.reshape((28, 28)), cmap='Greys_r')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)


fig.tight_layout(pad=0.1)

# %%
sess.close()

# %% [markdown]
# ## Denoising
#
# As I've mentioned before, autoencoders like the ones you've built so far aren't too useful in practive. However, they can be used to denoise images quite successfully just by training the network on noisy images. We can create the noisy images ourselves by adding Gaussian noise to the training images, then clipping the values to be between 0 and 1. We'll use noisy images as input and the original, clean images as targets. Here's an example of the noisy images I generated and the denoised images.
#
# ![Denoising autoencoder](assets/denoising.png)
#
#
# Since this is a harder problem for the network, we'll want to use deeper convolutional layers here, more feature maps. I suggest something like 32-32-16 for the depths of the convolutional layers in the encoder, and the same depths going backward through the decoder. Otherwise the architecture is the same as before.
#
# > **Exercise:** Build the network for the denoising autoencoder. It's the same as before, but with deeper layers. I suggest 32-32-16 for the depths, but you can play with these numbers, or add more layers.

# %%
learning_rate = 0.001
inputs_ = tf.placeholder(tf.float32, (None, 28, 28, 1), name='inputs')
targets_ = tf.placeholder(tf.float32, (None, 28, 28, 1), name='targets')

### Encoder
conv1 = tf.layers.conv2d(inputs_, 32, (3,3), padding='same')
# Now 28x28x32
maxpool1 = tf.layers.max_pooling2d(conv1, (3,3), (2,2), padding='same')
# Now 14x14x32
conv2 =  tf.layers.conv2d(maxpool1, 32, (3,3), padding='same')
# Now 14x14x32
maxpool2 = tf.layers.max_pooling2d(conv2, (3,3), (2,2), padding='same')
# Now 7x7x32
conv3 = tf.layers.conv2d(maxpool2, 16, (3,3), padding='same')
# Now 7x7x16
encoded = tf.layers.max_pooling2d(conv2, (1,1), (2,2))
# Now 4x4x16

### Decoder
upsample1 =  tf.image.resize_images(encoded, [7, 7])
# Now 7x7x16
conv4 = tf.layers.conv2d(upsample1, 16, (3,3), padding='same')
# Now 7x7x16
upsample2 = tf.image.resize_images(conv4, [14, 14])
# Now 14x14x16
conv5 = tf.layers.conv2d(upsample2, 32, (3,3), padding='same')
# Now 14x14x32
upsample3 = tf.image.resize_images(conv5, [28, 28])
# Now 28x28x32
conv6 = tf.layers.conv2d(upsample3, 32, (3,3), padding='same')
# Now 28x28x32



logits = tf.layers.conv2d(conv6, 1, (3,3), strides=(1,1), padding='same')
#Now 28x28x1

# Pass logits through sigmoid to get reconstructed image
decoded = tf.sigmoid(logits)

# Pass logits through sigmoid and calculate the cross-entropy loss
loss = tf.nn.sigmoid_cross_entropy_with_logits(labels=targets_, logits=logits)

# Get cost and define the optimizer
cost = tf.reduce_mean(loss)
opt = tf.train.AdamOptimizer(learning_rate).minimize(cost)

# %%
sess = tf.Session()

# %%
epochs = 10
batch_size = 200
# Set's how much noise we're adding to the MNIST images
noise_factor = 0.5
sess.run(tf.global_variables_initializer())
for e in range(epochs):
    for ii in range(mnist.train.num_examples//batch_size):
        batch = mnist.train.next_batch(batch_size)
        # Get images from the batch
        imgs = batch[0].reshape((-1, 28, 28, 1))
        
        # Add random noise to the input images
        noisy_imgs = imgs + noise_factor * np.random.randn(*imgs.shape)
        # Clip the images to be between 0 and 1
        noisy_imgs = np.clip(noisy_imgs, 0., 1.)
        
        # Noisy images as inputs, original images as targets
        batch_cost, _ = sess.run([cost, opt], feed_dict={inputs_: noisy_imgs,
                                                         targets_: imgs})

        if ii % 30 == 0:
            print("Epoch: {}/{}...".format(e+1, epochs), "Training loss: {:.4f}".format(batch_cost))
# Out:
# Epoch: 1/10... Training loss: 0.6877
# Epoch: 1/10... Training loss: 0.2569
# Epoch: 1/10... Training loss: 0.1831
# Epoch: 1/10... Training loss: 0.1676
# Epoch: 1/10... Training loss: 0.1518
# Epoch: 1/10... Training loss: 0.1445
# Epoch: 1/10... Training loss: 0.1405
# Epoch: 1/10... Training loss: 0.1369
# Epoch: 1/10... Training loss: 0.1328
# Epoch: 1/10... Training loss: 0.1352
# Epoch: 2/10... Training loss: 0.1310
# Epoch: 2/10... Training loss: 0.1298
# Epoch: 2/10... Training loss: 0.1293
# Epoch: 2/10... Training loss: 0.1256
# Epoch: 2/10... Training loss: 0.1243
# Epoch: 2/10... Training loss: 0.1268
# Epoch: 2/10... Training loss: 0.1266
# Epoch: 2/10... Training loss: 0.1258
# Epoch: 2/10... Training loss: 0.1262
# Epoch: 2/10... Training loss: 0.1227
# Epoch: 3/10... Training loss: 0.1209
# Epoch: 3/10... Training loss: 0.1275
# Epoch: 3/10... Training loss: 0.1232
# Epoch: 3/10... Training loss: 0.1201
# Epoch: 3/10... Training loss: 0.1198
# Epoch: 3/10... Training loss: 0.1176
# Epoch: 3/10... Training loss: 0.1205
# Epoch: 3/10... Training loss: 0.1204
# Epoch: 3/10... Training loss: 0.1180
# Epoch: 3/10... Training loss: 0.1229
# Epoch: 4/10... Training loss: 0.1200
# Epoch: 4/10... Training loss: 0.1184
# Epoch: 4/10... Training loss: 0.1237
# Epoch: 4/10... Training loss: 0.1213
# Epoch: 4/10... Training loss: 0.1174
# Epoch: 4/10... Training loss: 0.1199
# Epoch: 4/10... Training loss: 0.1166
# Epoch: 4/10... Training loss: 0.1171
# Epoch: 4/10... Training loss: 0.1164
# Epoch: 4/10... Training loss: 0.1166
# Epoch: 5/10... Training loss: 0.1200
# Epoch: 5/10... Training loss: 0.1161
# Epoch: 5/10... Training loss: 0.1199
# Epoch: 5/10... Training loss: 0.1176
# Epoch: 5/10... Training loss: 0.1140
# Epoch: 5/10... Training loss: 0.1129
# Epoch: 5/10... Training loss: 0.1184
# Epoch: 5/10... Training loss: 0.1176
# Epoch: 5/10... Training loss: 0.1140
# Epoch: 5/10... Training loss: 0.1184
# Epoch: 6/10... Training loss: 0.1182
# Epoch: 6/10... Training loss: 0.1186
# Epoch: 6/10... Training loss: 0.1178
# Epoch: 6/10... Training loss: 0.1171
# Epoch: 6/10... Training loss: 0.1165
# Epoch: 6/10... Training loss: 0.1190
# Epoch: 6/10... Training loss: 0.1118
# Epoch: 6/10... Training loss: 0.1185
# Epoch: 6/10... Training loss: 0.1135
# Epoch: 6/10... Training loss: 0.1175
# Epoch: 7/10... Training loss: 0.1170
# Epoch: 7/10... Training loss: 0.1139
# Epoch: 7/10... Training loss: 0.1152
# Epoch: 7/10... Training loss: 0.1128
# Epoch: 7/10... Training loss: 0.1146
# Epoch: 7/10... Training loss: 0.1167
# Epoch: 7/10... Training loss: 0.1132
# Epoch: 7/10... Training loss: 0.1159
# Epoch: 7/10... Training loss: 0.1132
# Epoch: 7/10... Training loss: 0.1144
# Epoch: 8/10... Training loss: 0.1148
# Epoch: 8/10... Training loss: 0.1150
# Epoch: 8/10... Training loss: 0.1168
# Epoch: 8/10... Training loss: 0.1150
# Epoch: 8/10... Training loss: 0.1135
# Epoch: 8/10... Training loss: 0.1143
# Epoch: 8/10... Training loss: 0.1149
# Epoch: 8/10... Training loss: 0.1136
# Epoch: 8/10... Training loss: 0.1125
# Epoch: 8/10... Training loss: 0.1131
# Epoch: 9/10... Training loss: 0.1143
# Epoch: 9/10... Training loss: 0.1128
# Epoch: 9/10... Training loss: 0.1175
# Epoch: 9/10... Training loss: 0.1155
# Epoch: 9/10... Training loss: 0.1136
# Epoch: 9/10... Training loss: 0.1130
# Epoch: 9/10... Training loss: 0.1134
# Epoch: 9/10... Training loss: 0.1139
# Epoch: 9/10... Training loss: 0.1158
# Epoch: 9/10... Training loss: 0.1170
# Epoch: 10/10... Training loss: 0.1123
# Epoch: 10/10... Training loss: 0.1132
# Epoch: 10/10... Training loss: 0.1116
# Epoch: 10/10... Training loss: 0.1104
# Epoch: 10/10... Training loss: 0.1143
# Epoch: 10/10... Training loss: 0.1126
# Epoch: 10/10... Training loss: 0.1136
# Epoch: 10/10... Training loss: 0.1125
# Epoch: 10/10... Training loss: 0.1134
# Epoch: 10/10... Training loss: 0.1124

# %% [markdown]
# ## Checking out the performance
#
# Here I'm adding noise to the test images and passing them through the autoencoder. It does a suprisingly great job of removing the noise, even though it's sometimes difficult to tell what the original number is.

# %%
fig, axes = plt.subplots(nrows=2, ncols=10, sharex=True, sharey=True, figsize=(20,4))
in_imgs = mnist.test.images[:10]
noisy_imgs = in_imgs + noise_factor * np.random.randn(*in_imgs.shape)
noisy_imgs = np.clip(noisy_imgs, 0., 1.)

reconstructed = sess.run(decoded, feed_dict={inputs_: noisy_imgs.reshape((10, 28, 28, 1))})

for images, row in zip([noisy_imgs, reconstructed], axes):
    for img, ax in zip(images, row):
        ax.imshow(img.reshape((28, 28)), cmap='Greys_r')
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)

fig.tight_layout(pad=0.1)
